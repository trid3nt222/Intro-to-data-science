# %% [markdown]
# <a href="https://colab.research.google.com/github/trid3nt222/Intro-to-data-science/blob/main/DAY%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(10)
# Out:
# 10

# %%
Current_year=2026
Birth_year=2008
Age=Current_year-Birth_year
print(Age)
# Out:
# 18

# %%
print(2026-2008)
# Out:
# 18

# %%
Name="Jane"
Name="Abby"
print(Name)
# Out:
# Abby

# %%
print("My name is Trivence")
# Out:
# My name is Trivence

# %%
print("I am 18 years old")
# Out:
# I am 18 years old

# %%
print("My hobby is swimming")
# Out:
# My hobby is swimming

# %%
Name="Trivence"
print("My name is",Name)
# Out:
# My name is Trivence

# %%
Age=18
print("I am",Age,"years old")
# Out:
# I am 18 years old

# %%
Hobby="swimming"
print("My hobby is",Hobby)
# Out:
# My hobby is swimming

# %%
print("Hello","World")
# Out:
# Hello World

# %%
name="John"
print(f"My name is {name}")
# Out:
# My name is John
