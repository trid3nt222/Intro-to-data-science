# %% [markdown]
# <a href="https://colab.research.google.com/github/trid3nt222/Intro-to-data-science/blob/main/DAY_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Input**

# %%
name=input("What is your name ")
# Out:
# What is your name Jane

# %%
print(name)
# Out:
# Jane

# %%
name=input("What is your name? ")
food=input("What is your favourite food? ")
sport=input("What is your favourite sport? ")
print(f"Hello {name}!")
print(f"You like {food}.")
print(f"You're favourite sport is {sport}.")
# Out:
# What is your name? Jane
# What is your favourite food? Pizza
# What is your favourite sport? Tennis
# Hello Jane!
# You like Pizza.
# You're favourite sport is Tennis.

# %%
print("Hello", name+"!")
# Out:
# Hello Jane!

# %% [markdown]
# # Type

# %%
type("Hello")
# Out:
# str

# %%
type(10)
# Out:
# int

# %%
print(type(10))
# Out:
# <class 'int'>

# %% [markdown]
# # Data types

# %%
x=2
y=3.4

# %%
name="Jane"

# %%
is_raining=True
is_sunny=False

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(is_raining))
# Out:
# <class 'bool'>

# %% [markdown]
# # Operators

# %%
print(1+1)
print(10-2)
print(20/2)
print(20*2)
print(5//2)
print(5%2)
print(2**2)
# Out:
# 2
# 8
# 10.0
# 40
# 2
# 1
# 4

# %% [markdown]
# # Type casting

# %%
x=10
print(type(x))
# Out:
# <class 'int'>

# %%
x=float(x)
print(x)
print(type(x))
# Out:
# 10.0
# <class 'float'>

# %%
age=input("What is your age? ")
print(type(age))
# Out:
# What is your age? 18
# <class 'str'>

# %%
age=int(input("What is your age? "))
print(type(age))
# Out:
# What is your age? 18
# <class 'int'>

# %%
temp=float(input("What is your body temperature in degrees celsuis? "))
print("Tempertature in farenheit:", (temp*1.8)+32)
# Out:
# What is your body temperature in degrees celsuis? 36
# Tempertature in farenheit: 96.8

# %%
x=float(input("What is x "))
y=float(input("What is y "))

print("Addition:",x+y)
print("Subtraction:",x-y)
print("Muliplication",x*y)
print("x divide by y:",x/y)
print("Floor division:",x//y)
print("Modulus:",x%y)
print("x power y:",x**y)
# Out:
# What is x 10
# What is y 5
# Addition: 15.0
# Subtraction: 5.0
# Muliplication 50.0
# x divide by y: 2.0
# Floor division: 2.0
# Modulus: 0.0
# x power y: 100000.0
