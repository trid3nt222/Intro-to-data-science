# %% [markdown]
# <a href="https://colab.research.google.com/github/trid3nt222/Intro-to-data-science/blob/main/Day_4_morning_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day 4 morning tasks

# %%
#36
letter=input("Letter: ")
if letter=="a" or letter=="e" or letter=="i" or letter=="o" or letter=="u":
  print("vowel")
elif letter=="y":
  print("sometimes y is a vowel, and sometimes it's a consonant")
else:
  print("consonant")
# Out:
# Letter: x
# consonant

# %%
#39
Jackhammer=130
Gas_lawnmower=106
Alarm_clock=70
Quiet_room=40
decibel_level=int(input("sound level in decibels: "))
if decibel_level==130:
  print("Jackhammer")
elif decibel_level==106:
  print("Gas lawnmower")
elif decibel_level==70:
  print("Alarm clock")
elif decibel_level==40:
  print("Quiet room")
elif decibel_level>40 and decibel_level<70:
  print("noise is between quiet room and alarm clock")
elif decibel_level>70 and decibel_level<106:
  print("noise is between alarm clock and gas lawnmower")
elif decibel_level>106 and decibel_level<130:
  print("noise is between gas lawnmower and jackhammer")
elif decibel_level<40:
  print("noise is lower than that of quiet room")
else:
  print("noise is above that of jackhammer")
# Out:
# sound level in decibels: 50
# noise is between quiet room and alarm clock

# %%
#45
letter=input("Enter letter: ")
if letter=="a" or letter=="c" or letter=="e" or letter=="g":
  x=1
else:
 x=2
number=input("Enter number: ")
if number=="1" or number=="3" or number=="5" or number=="7":
  y=1
else:
  y=2

position=(letter+number)
if position==2:
  print("white")
else:
  print("black")
# Out:
# Enter letter: g
# Enter number: 3
# black
